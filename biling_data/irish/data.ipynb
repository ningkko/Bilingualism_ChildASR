# %% [markdown]
# ### Data

# %%
import pandas as pd

# %%
df = pd.read_spss("WandSAllVariables_Items for WordBank.SAV")
len(df.columns)
# Out:
# 1368

# %%
instruction = pd.read_csv("Irish_English.csv")
instruction
# Out:
#                 item     itemID                   type  \
# 0               ahah     item_1  ANIMALS (Real or toy)
# 1             baabaa     item_2  ANIMALS (Real or toy)
# 2             bowwow     item_3  ANIMALS (Real or toy)
# 3           choochoo     item_4                CLOTHES
# 4     cockadoodledoo     item_5                CLOTHES
# ...              ...        ...                    ...
# 1348              if  item_1349                CLOTHES
# 1349             mar  item_1350                CLOTHES
# 1350         because  item_1351                CLOTHES
# 1351           nuair  item_1352                CLOTHES
# 1352            when  item_1353                CLOTHES
#
#                         choices  complexity_category      definition
# 0     produces; doesn't produce                  NaN            ahah
# 1     produces; doesn't produce                  NaN          baabaa
# 2     produces; doesn't produce                  NaN          bowwow
# ...

# %%
new_columns = df.columns[0:10].to_list() + instruction.itemID.to_list() + df.columns[-5:].to_list()
new_columns
# Out:
# ['CHIID',
#  'SessionNo',
#  'age',
#  'gender',
#  'BirthOrder',
#  'MainCaregiverIrish',
#  'MainCaregiverEnglish',
#  'LanguageHousehold',
#  'MotherEducationESS',
#  'FatherEducationESS',
#  'item_1',
#  'item_2',
#  'item_3',
#  'item_4',
#  'item_5',
#  'item_6',
#  'item_7',
#  'item_8',
#  'item_9',
#  'item_10',
#  'item_11',
#  'item_12',
#  'item_13',
#  'item_14',
#  'item_15',
#  'item_16',
#  'item_17',
#  'item_18',
#  'item_19',
#  'item_20',
#  'item_21',
#  'item_22',
#  'item_23',
#  'item_24',
#  'item_25',
#  'item_26',
#  'item_27',
#  'item_28',
#  'item_29',
#  'item_30',
#  'item_31',
#  'item_32',
#  'item_33',
#  'item_34',
#  'item_35',
#  'item_36',
#  'item_37',
#  'item_38',
#  'item_39',
#  'item_40',
#  'item_41',
#  'item_42',
#  'item_43',
#  'item_44',
#  'item_45',
#  'item_46',
#  'item_47',
#  'item_48',
#  'item_49',
#  'item_50',
#  'item_51',
#  'item_52',
#  'item_53',
#  'item_54',
#  'item_55',
#  'item_56',
#  'item_57',
#  'item_58',
# ...

# %%
pd.read_csv("DanishWS_Bleses_data.csv")
# Out:
# /opt/homebrew/anaconda3/envs/biling/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,785,800,801,889,890,891,906,907,908,923,924,926,927,939,944,953,954,955) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      barn_id size_group_additional work_hours_class_f work_hours_class_m  \
# 0      T0001                   NaN              41-50              21-30
# 1      T0002                   NaN            missing            missing
# 2      T0003                   NaN              31-40              21-30
# 3      T0004                   NaN              31-40              31-40
# 4      T0005                   NaN              61-70              21-30
# ...      ...                   ...                ...                ...
# 3709  UT0936                   NaN              41-50              31-40
# ...

# %%
df.columns = new_columns

# %%
df.to_csv("Irish_English_data.csv",index = False)

# %% [markdown]
# ### Fields

# %%
# Out:
#     CHIID  SessionNo   age gender  BirthOrder MainCaregiverIrish  \
# 0   101.0        1.0  35.0   Boys         4.0             Always
# 1   102.0        1.0  19.0   girl         5.0             Always
# 2   102.0        2.0  26.0   girl         5.0             Always
# 3   103.0        1.0  34.0   girl         2.0             Always
# 4   104.0        1.0  30.0   Boys         1.0             Always
# ..    ...        ...   ...    ...         ...                ...
# 94  402.0        1.0  36.0   girl         2.0              50:50
# 95  501.0        1.0  28.0   girl         1.0             Always
# 96  503.0        1.0  25.0   girl         2.0             Always
# 97  504.0        1.0  23.0   girl         3.0            Usually
# 98  505.0        1.0  24.0   girl         1.0             Always
#
#    MainCaregiverEnglish        LanguageHousehold  MotherEducationESS  \
# 0          Never/rarely             Mostly Irish                 3.0
# ...
